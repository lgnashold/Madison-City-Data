# %%
import pandas as pd
from pandas import Series, DataFrame
import matplotlib
matplotlib.rcParams.update({'font.size':15})
matplotlib.rcParams.update({'figure.figsize': [6, 6]})
# %matplotlib inline

all_data = pd.read_csv('s19-city/data/spend.csv');
streets_dataset = all_data[all_data["Agency"].str.startswith("44")]

#print(streets_dataset);
#print(f"Number of data points: {len(city_data)}")

# %%
# Billing: Expense, with parens, all negative
int_billing = all_data[all_data["Character Code"].str.startswith("58")]
# Charges: Also expense, sometimes has parens, mostly positive but a few negative
int_charges = all_data[all_data["Character Code"].str.startswith("57")]
charges_tot = int_charges["2018"].sum()
charges_tot_abs = int_charges["2018"].abs().sum()
print("Net charges: " + str(charges_tot) + " Total charges: " +  str(charges_tot_abs))
df = Series({"Billing":int_billing["2018"].abs().sum()/1000000, "Charges":int_charges["2018"].abs().sum()/1000000})
ax = df.plot.bar(figsize = (10, 10))
ax.set_ylabel("Expense in Millions of Dollars")
ax.set_xlabel("")
ax.set_title("Total Interdepartmental Billing and Charges")
# Out:
# Net charges: 20639464.950000003 Total charges: 20973758.75
# Text(0.5, 1.0, 'Total Interdepartmental Billing and Charges')

# %%
# Creates list of agencies
agencies = all_data["Agency"].str[6:21].unique()
print(agencies)
# Out:
# ['LIBRARY' 'PARKS' 'STREETS' 'PLANNING' 'MUNICIPAL COURT' 'FIRE'
#  'ENGINEERING' 'UNDEFINED' 'POLICE' 'TRAFFIC ENGINEE' 'HUMAN RESOURCES'
#  'INFORMATION TEC' 'MAYOR' 'COMMUNITY DEVEL' 'BUILDING INSPEC' 'ATTORNEY'
#  'FINANCE' 'COMMON COUNCIL' 'ECONOMIC DEVELO' 'CLERK' 'TREASURER'
#  'PCED OFFICE OF ' 'ASSESSOR' 'CIVIL RIGHTS' 'TRANSPORTATION'
#  'EMPLOYEE ASSIST' 'CITY WIDE MISCE']

# %%
# All data
charges_multilevel = int_charges.copy()
charges_multilevel["Agency"] = charges_multilevel["Agency"].str[6:]
charges_multilevel["Object"] = charges_multilevel["Object"].str[18:]

charges_multilevel = charges_multilevel.groupby(["Agency", "Object"]).sum().abs()["2018"]
charges_multilevel = charges_multilevel[charges_multilevel != 0]

top_agencies = charges_multilevel.copy()
top_agencies = top_agencies.filter(regex='FIRE|POLICE|PARKS|STREETS', axis=0)

other = charges_multilevel.copy()
other = other.filter(regex = '^((?!(FIRE|STREETS|POLICE|PARKS)).)*$', axis = 0)
other = other.rename(lambda s:"Other", level=0 ).groupby(["Agency", "Object"]).sum()

result = other.append(top_agencies)
result = result.rename(lambda s:s.title())
result = result.sort_values(ascending = False)
#charges_multilevel = charges_multilevel[charges_multilevel >= 150000]
print(result)

result.to_csv("~/data2.csv")


#print(charges_multilevel)
#objects = billing.groupby([column2])["2018"].sum().abs().sort_values(ascending=False).head(10)
# Out:
# Agency   Object
# Streets  From Fleet Services     7331039.25
# Fire     From Fleet Services     2627818.02
# Police   From Fleet Services     2407865.01
# Parks    From Fleet Services     1885951.60
# Police   From Insurance           998518.00
# Fire     From Workers Comp        859647.00
# Police   From Workers Comp        835092.00
#          From Engineering         611303.00
# Streets  From Workers Comp        398717.00
# Other    From Engineering         388705.07
#          From Fleet Services      310283.72
#          From Insurance           281298.00
# Fire     From Engineering         278163.00
# Police   From Traffic Enginee     273847.41
# Parks    From Workers Comp        273306.00
# Other    From Workers Comp        272793.00
# Parks    From Insurance           176555.00
# Fire     From Traffic Enginee     120575.71
# Streets  From Insurance           115286.00
# Fire     From Insurance           101277.00
# Other    From Community Devel      90000.00
# Streets  From Engineering          55152.00
#          From Traffic Enginee      33274.00
# Parks    From Traffic Enginee      29230.54
# Other    From Information Tec      23940.00
# Parks    From Engineering          14111.00
# Other    From Traffic Enginee       8748.76
# Name: 2018, dtype: float64
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.

# %%
# data between agencies for charges
charge = int_charges.copy()
charge["Agency"] = charge["Agency"].str[6:21]
charge["Object"] = charge["Object"].str[23:]

charge = charge[charge["Object"].isin(agencies)]

charge = charge.groupby(["Agency", "Object"]).sum()["2018"]
charge = charge[charge != 0]

charge = charge.rename(lambda s:s.title())

#print(charge)

# Data between agencies for billing
bill = int_billing.copy()
bill["Agency"] = bill["Agency"].str[6:21]
bill["Object"] = bill["Object"].str[22:]


bill = bill[bill["Object"].isin(agencies)]

bill = bill.groupby(["Agency", "Object"]).sum()["2018"]
bill = bill[bill != 0]

bill = bill.rename(lambda s:s.title())

print(bill)
print(charge)

bill.abs().to_csv("~/Projects/DataAnalysis/billing_agency_only.csv")

charge.abs().to_csv("~/Projects/DataAnalysis/charges_agency_only.csv")


no_descrep = 0
for i in charge.items():
    agency = i[0][0]
    obj = i[0][1]
    ag1 = charge[agency][obj]
    try:
        ag2 = bill[obj][agency]
    except:
        ag2 = 0
    dif = (int)(ag1 + ag2)
    if (dif != 0):
        print(agency + " => "   + obj)
        print("\tCharge: $" + str(int(ag1))+ " Billing: $" + str(int(ag2)))
        print("\tDiscrepancy $" + str(dif) + " \n")
    else: 
        no_descrep += 1
print("Combinations without discrepancies: " + str(no_descrep))
# Out:
# Agency           Object
# Community Devel  Municipal Court    -90000.00
# Engineering      Building Inspec    -62598.00
#                  Community Devel    -38090.00
#                  Economic Develo    -59539.00
#                  Engineering        -13080.00
#                  Fire              -278163.00
#                  Human Resources    -33767.00
#                  Information Tec      -969.00
#                  Library             -3537.00
#                  Parks              -14111.00
#                  Planning           -79364.00
#                  Police            -611303.00
#                  Streets            -55152.00
#                  Traffic Enginee    -54539.00
# Information Tec  Library            -23940.00
# Planning         Community Devel    -41500.00
# Traffic Enginee  Building Inspec     -1698.70
#                  Clerk                -970.97
#                  Engineering         -6856.86
#                  Fire              -120575.71
#                  Library             -3658.58
#                  Parks              -31139.55
#                  Police            -277014.80
#                  Streets            -31922.67
# Name: 2018, dtype: float64
# Agency           Object
# Building Inspec  Engineering         62598.00
#                  Traffic Enginee       814.37
# Clerk            Traffic Enginee       970.97
# Community Devel  Engineering         38090.00
# Economic Develo  Engineering         59539.00
# Engineering      Engineering         13080.00
#                  Traffic Enginee      3304.84
# Fire             Engineering        278163.00
#                  Traffic Enginee    120575.71
# Human Resources  Engineering         33767.00
# Information Tec  Engineering           969.00
# Library          Engineering          3537.00
#                  Information Tec     23940.00
#                  Traffic Enginee      3658.58
# Municipal Court  Community Devel     90000.00
# Parks            Engineering         14111.00
#                  Traffic Enginee     29230.54
# Pced Office Of   Engineering         16245.00
# Planning         Engineering         79364.00
# Police           Engineering        611303.00
#                  Traffic Enginee    273847.41
# Streets          Engineering         55152.00
#                  Traffic Enginee     33274.00
# Traffic Enginee  Engineering        -81516.07
# Name: 2018, dtype: float64
# Building Inspec => Traffic Enginee
# 	Charge: $814 Billing: $-1698
# 	Discrepancy $-884
#
# Engineering => Traffic Enginee
# 	Charge: $3304 Billing: $-6856
# 	Discrepancy $-3552
#
# Parks => Traffic Enginee
# 	Charge: $29230 Billing: $-31139
# 	Discrepancy $-1909
#
# Pced Office Of  => Engineering
# 	Charge: $16245 Billing: $0
# 	Discrepancy $16245
#
# Police => Traffic Enginee
# 	Charge: $273847 Billing: $-277014
# 	Discrepancy $-3167
#
# Streets => Traffic Enginee
# 	Charge: $33274 Billing: $-31922
# 	Discrepancy $1351
#
# Traffic Enginee => Engineering
# 	Charge: $-81516 Billing: $-54539
# 	Discrepancy $-136055
#
# Combinations without discrepancies: 17
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:31: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:33: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.

# %%
charge = int_charges.copy()
charge["Agency"] = charge["Agency"].str[6:21]
charge["Object"] = charge["Object"].str[23:]
charge = charge[charge["Agency"].str.contains("TRAFFIC") | charge["Object"].str.contains("TRAFFIC")]

# Data between agencies for billing
bill = int_billing.copy()
bill["Agency"] = bill["Agency"].str[6:21]
bill["Object"] = bill["Object"].str[22:]
bill = bill[bill["Agency"].str.contains("TRAFFIC") | bill["Object"].str.contains("TRAFFIC")]

print(bill)
print(charge)

for i in bill.itertuples():
    agency = i[0][0]
    obj = i[0][1]
    ag1 = charge[agency][obj]
    try:
        ag2 = bill[obj][agency]
    except:
        ag2 = 0
    dif = (int)(ag1 + ag2)
    if (dif != 0):
        print(agency + " => "   + obj)
        print("\tCharge: $" + str(int(ag1))+ " Billing: $" + str(int(ag2)))
        print("\tDiscrepancy $" + str(dif) + " \n")
    else: 
        no_descrep += 1
print("Combinations without discrepancies: " + str(no_descrep))
# Out:
#                Agency                     Organization Account Type  \
# 17    TRAFFIC ENGINEE                  45400 - TE COMM      Expense
# 42    TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
# 47    TRAFFIC ENGINEE                  45400 - TE COMM      Expense
# 71        ENGINEERING      40470 - ENG FAC MAINT ADMIN      Expense
# 75    TRAFFIC ENGINEE                  45400 - TE COMM      Expense
# 100   TRAFFIC ENGINEE                  45400 - TE COMM      Expense
# 102   TRAFFIC ENGINEE                  45400 - TE COMM      Expense
# 105   TRAFFIC ENGINEE   45505 - TE SIGNALS MAINTENANCE      Expense
# 109   TRAFFIC ENGINEE                  45400 - TE COMM      Expense
# 125   TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
# 135   TRAFFIC ENGINEE   45505 - TE SIGNALS MAINTENANCE      Expense
# 146   TRAFFIC ENGINEE   45505 - TE SIGNALS MAINTENANCE      Expense
# 153   TRAFFIC ENGINEE   45505 - TE SIGNALS MAINTENANCE      Expense
# 158   TRAFFIC ENGINEE                  45400 - TE COMM      Expense
# 168   TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
# 190   TRAFFIC ENGINEE                  45400 - TE COMM      Expense
# 192   TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
# 198   TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
# 202   TRAFFIC ENGINEE               45500 - TE SIGNALS      Expense
# 210   TRAFFIC ENGINEE   45505 - TE SIGNALS MAINTENANCE      Expense
# 216   TRAFFIC ENGINEE                  45400 - TE COMM      Expense
# 218   TRAFFIC ENGINEE                  45400 - TE COMM      Expense
# 225   TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
# 226   TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
# 233   TRAFFIC ENGINEE                  45400 - TE COMM      Expense
# 236   TRAFFIC ENGINEE                  45400 - TE COMM      Expense
# 241   TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
# 255           STREETS  44330 - ST SNOW PLOW AND SPREAD      Expense
# 261   TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
# 263   TRAFFIC ENGINEE                  45400 - TE COMM      Expense
# 270   TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
# 275   TRAFFIC ENGINEE   45505 - TE SIGNALS MAINTENANCE      Expense
# 277   TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
# 281   TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
# 286   TRAFFIC ENGINEE               45500 - TE SIGNALS      Expense
# 299   TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
# 301   TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
# 315   TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
# 339   TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
# 346   TRAFFIC ENGINEE                  45400 - TE COMM      Expense
# 363   TRAFFIC ENGINEE      45405 - TE COMM MAINTENANCE      Expense
# 366   TRAFFIC ENGINEE      45405 - TE COMM MAINTENANCE      Expense
# 376   TRAFFIC ENGINEE      45405 - TE COMM MAINTENANCE      Expense
# 384   TRAFFIC ENGINEE      45405 - TE COMM MAINTENANCE      Expense
# 390   TRAFFIC ENGINEE                  45400 - TE COMM      Expense
# 394   TRAFFIC ENGINEE      45405 - TE COMM MAINTENANCE      Expense
# 397   TRAFFIC ENGINEE      45405 - TE COMM MAINTENANCE      Expense
# 404   TRAFFIC ENGINEE      45405 - TE COMM MAINTENANCE      Expense
# 405   TRAFFIC ENGINEE      45405 - TE COMM MAINTENANCE      Expense
# 411   TRAFFIC ENGINEE                  45400 - TE COMM      Expense
# 417   TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
# 447   TRAFFIC ENGINEE      45405 - TE COMM MAINTENANCE      Expense
# 451   TRAFFIC ENGINEE               45200 - TE STLIGHT      Expense
# 7408  TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
# 7409  TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
# 7414  TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
# 7696  TRAFFIC ENGINEE               45500 - TE SIGNALS      Expense
# 8324  TRAFFIC ENGINEE               45100 - TE SIGNING      Expense
#
#                  Character Code           Object       2015       2016  \
# 17    58 - INTER DEPART BILLING             FIRE -265582.98  -36300.30
# 42    58 - INTER DEPART BILLING      ENGINEERING  -95278.75   -1667.07
# 47    58 - INTER DEPART BILLING           POLICE  -87143.27 -211410.47
# 71    58 - INTER DEPART BILLING  TRAFFIC ENGINEE  -54539.00  -54540.00
# 75    58 - INTER DEPART BILLING          TRANSIT  -52505.88   -1141.52
# 100   58 - INTER DEPART BILLING            PARKS  -34768.37   -1623.26
# 102   58 - INTER DEPART BILLING          STREETS  -32334.40  -32301.47
# 105   58 - INTER DEPART BILLING  INFORMATION TEC  -31500.91       0.00
# 109   58 - INTER DEPART BILLING            WATER  -28477.98   -4600.39
# 125   58 - INTER DEPART BILLING          TRANSIT  -22315.85  -19477.23
# 135   58 - INTER DEPART BILLING          PARKING  -17998.50   -3842.66
# 146   58 - INTER DEPART BILLING            PARKS  -15053.48       0.00
# 153   58 - INTER DEPART BILLING          STREETS  -11662.70       0.00
# 158   58 - INTER DEPART BILLING      ENGINEERING  -10850.86   -9809.99
# 168   58 - INTER DEPART BILLING          PARKING   -8821.01  -38906.22
# 190   58 - INTER DEPART BILLING       STORMWATER   -5388.10   -6755.52
# 192   58 - INTER DEPART BILLING            PARKS   -5246.22   -2596.92
# 198   58 - INTER DEPART BILLING   FLEET SERVICES   -4469.34   -2092.64
# 202   58 - INTER DEPART BILLING             FIRE   -4306.05       0.00
# 210   58 - INTER DEPART BILLING            WATER   -3604.55   -1782.16
# 216   58 - INTER DEPART BILLING          LIBRARY   -3188.58       0.00
# 218   58 - INTER DEPART BILLING  BUILDING INSPEC   -3022.82       0.00
# 225   58 - INTER DEPART BILLING   CDA MANAGEMENT   -2667.67    -490.15
# 226   58 - INTER DEPART BILLING          STREETS   -2616.01   -3062.08
# 233   58 - INTER DEPART BILLING   FLEET SERVICES   -2176.21       0.00
# 236   58 - INTER DEPART BILLING          PARKING   -2105.69   -2103.35
# 241   58 - INTER DEPART BILLING             FIRE   -1970.36   -3684.30
# 255   58 - INTER DEPART BILLING  TRAFFIC ENGINEE   -1425.00       0.00
# 261   58 - INTER DEPART BILLING            WATER   -1247.12   -1209.88
# 263   58 - INTER DEPART BILLING  PUBLIC HEALTH M   -1081.01   -1505.42
# 270   58 - INTER DEPART BILLING            CLERK    -929.64    -867.20
# 275   58 - INTER DEPART BILLING      ENGINEERING    -849.08       0.00
# 277   58 - INTER DEPART BILLING           POLICE    -812.59   -1033.38
# 281   58 - INTER DEPART BILLING       STORMWATER    -688.02       0.00
# 286   58 - INTER DEPART BILLING   FLEET SERVICES    -539.69       0.00
# 299   58 - INTER DEPART BILLING   MONONA TERRACE    -359.50    -342.64
# 301   58 - INTER DEPART BILLING            SEWER    -314.38       0.00
# 315   58 - INTER DEPART BILLING          LIBRARY    -162.72       0.00
# 339   58 - INTER DEPART BILLING  PUBLIC HEALTH M     -59.85       0.00
# 346   58 - INTER DEPART BILLING  INFORMATION TEC     -41.11       0.00
# 363   58 - INTER DEPART BILLING             FIRE       0.00  -76112.33
# 366   58 - INTER DEPART BILLING          TRANSIT       0.00  -51500.08
# 376   58 - INTER DEPART BILLING            PARKS       0.00  -14715.09
# 384   58 - INTER DEPART BILLING            WATER       0.00   -5065.67
# 390   58 - INTER DEPART BILLING            SEWER       0.00   -3090.88
# 394   58 - INTER DEPART BILLING  BUILDING INSPEC       0.00   -2015.90
# 397   58 - INTER DEPART BILLING          LIBRARY       0.00   -1550.13
# 404   58 - INTER DEPART BILLING  PUBLIC HEALTH M       0.00    -574.56
# 405   58 - INTER DEPART BILLING   FLEET SERVICES       0.00    -468.72
# 411   58 - INTER DEPART BILLING         LANDFILL       0.00    -265.07
# 417   58 - INTER DEPART BILLING  BUILDING INSPEC       0.00     -40.68
# 447   58 - INTER DEPART BILLING       STORMWATER       0.00       0.00
# 451   58 - INTER DEPART BILLING  TRAFFIC ENGINEE       0.00       0.00
# 7408  58 - INTER DEPART BILLING     GOLF COURSES        NaN   -1180.90
# 7409  58 - INTER DEPART BILLING    TAX INCREMENT        NaN    -824.18
# 7414  58 - INTER DEPART BILLING         PLANNING        NaN     -97.60
# 7696  58 - INTER DEPART BILLING          PARKING        NaN       0.00
# 8324  58 - INTER DEPART BILLING              CDA        NaN        NaN
#
#            2017       2018
# 17    -14247.58  -42653.58
# 42      -188.13    -550.00
# 47   -213879.05 -276914.76
# 71    -54539.00  -54539.00
# 75      -616.19     -90.68
# 100    -2509.82     -16.44
# 102   -35693.43  -30888.92
# 105        0.00       0.00
# 109      -41.11  -14233.35
# 125   -19965.63  -13279.01
# 135        0.00       0.00
# 146        0.00       0.00
# 153        0.00       0.00
# 158    -8734.21   -6306.86
# 168   -36828.17   -9098.84
# 190     -820.84   -6046.83
# 192    -7853.70   -2606.22
# 198    -2540.21   -7644.76
# 202        0.00       0.00
# 210        0.00       0.00
# 216        0.00    -470.00
# 218        0.00   -1698.70
# 225        0.00    -139.78
# 226    -2544.87   -1033.75
# 233        0.00       0.00
# 236    -3882.93   -5875.76
# 241    -1534.96   -1948.70
# 255        0.00       0.00
# 261     -305.82   -5890.37
# 263    -1466.77   -2063.97
# 270    -1098.20    -970.97
# 275        0.00       0.00
# 277     -638.70    -100.04
# 281      -51.72    -275.00
# 286        0.00       0.00
# 299      -50.15       0.00
# 301     -122.20    -275.00
# 315      -71.53       0.00
# 339     -178.50       0.00
# 346        0.00       0.00
# 363   -91229.65  -75973.43
# 366   -52936.14  -54073.80
# 376   -17298.65  -28516.89
# 384    -6334.11    -383.67
# 390        0.00       0.00
# 394     -840.11       0.00
# 397    -1659.36   -3188.58
# 404    -1619.19    -114.64
# 405     -468.72   -1344.62
# 411        0.00       0.00
# 417      -81.36       0.00
# 447     -717.35       0.00
# 451     -201.20       0.00
# 7408       0.00       0.00
# 7409       0.00       0.00
# 7414       0.00       0.00
# 7696       0.00       0.00
# 8324        NaN    -301.14
#                Agency                            Organization Account Type  \
# 59    TRAFFIC ENGINEE                      45500 - TE SIGNALS      Expense
# 61    TRAFFIC ENGINEE                      45500 - TE SIGNALS      Expense
# 114   TRAFFIC ENGINEE                      45200 - TE STLIGHT      Expense
# 820             PARKS     51310 - PARK PLANNING DEVELOP ADMIN      Expense
# 1235  TRAFFIC ENGINEE                     45600 - TE SERVICES      Expense
# 1334            PARKS       51170 - PARK COM REC GOODMAN POOL      Expense
# 1485            PARKS           51245 - PARK MTC CONSTRUCTION      Expense
# 1493            PARKS           51210 - PARK MTC FOREST ADMIN      Expense
# 1757            PARKS                    51147 - PARK RANGERS      Expense
# 1960  TRAFFIC ENGINEE                         45400 - TE COMM      Expense
# 2462  INFORMATION TEC           17200 - IT TECHNICAL SERVICES      Expense
# 2467            PARKS       51160 - PARK COM REC REC SERVICES      Expense
# 3550          STREETS            44662 - ST GRAFFITI REMOVALS      Expense
# 3551          STREETS                 44660 - ST WEED CONTROL      Expense
# 3552          STREETS            44333 - ST SNOW SAND BARRELS      Expense
# 3721            PARKS           51246 - PARK MTC CONSERVATION      Expense
# 3898            PARKS             51241 - PARK MTC EAST PARKS      Expense
# 4037            PARKS          51243 - PARK MTC CENTRAL PARKS      Expense
# 4084          STREETS                        44551 - ST STONE      Expense
# 4085          STREETS       44332 - ST SNOW REMOVAL CROSSWALK      Expense
# 4086          STREETS             44224 - ST BRUSH PROCESSING      Expense
# 4141      ENGINEERING          40139 - ENG MEDIAN MAINTENANCE      Expense
# 4271            CLERK                           13100 - CLERK      Expense
# 4288      ENGINEERING    40471 - ENG FAC MAINT BUILDING MAINT      Expense
# 4426          STREETS               44661 - ST STUMP REMOVALS      Expense
# 4427          STREETS             44223 - ST BRUSH COLLECTION      Expense
# 4494            PARKS             51242 - PARK MTC WEST PARKS      Expense
# 4632  TRAFFIC ENGINEE                      45100 - TE SIGNING      Expense
# 4678          STREETS              44221 - ST LEAF COLLECTION      Expense
# 4865          STREETS                  44111 - ST LARGE ITEMS      Expense
# ...               ...                                     ...          ...
# 5232          STREETS                     44550 - ST BLACKTOP      Expense
# 5234  BUILDING INSPEC                   60100 - BI INSPECTION      Expense
# 5279          LIBRARY       50400751 - LIB FACILITIES CENTRAL      Expense
# 5467          STREETS               44222 - ST DROP OFF SITES      Expense
# 5565      ENGINEERING              40110 - ENG ADMIN DIVISION      Expense
# 5654  TRAFFIC ENGINEE                    45300 - TE PAVE MARK      Expense
# 5672          STREETS         44220 - ST RECYCLING COLLECTION      Expense
# 5751          STREETS            44110 - ST REFUSE COLLECTION      Expense
# 5795          STREETS         44330 - ST SNOW PLOW AND SPREAD      Expense
# 6031            PARKS       51220 - PARK MTC FORESTRY GENERAL      Expense
# 6052  TRAFFIC ENGINEE  45800 - TE BICYCLE AND PEDESTRIAN SVCS      Expense
# 6112  TRAFFIC ENGINEE                      45100 - TE SIGNING      Expense
# 6113  TRAFFIC ENGINEE                     45600 - TE SERVICES      Expense
# 6251            PARKS         51244 - PARK MTC MALL CONCOURSE      Expense
# 6350  TRAFFIC ENGINEE                      45500 - TE SIGNALS      Expense
# 6555            PARKS   51230 - PARK MTC FACILITY MAINTENANCE      Expense
# 6726           POLICE                  31200 - POLICE SUPPORT      Expense
# 6833  TRAFFIC ENGINEE                      45200 - TE STLIGHT      Expense
# 6847  TRAFFIC ENGINEE                      45500 - TE SIGNALS      Expense
# 6983  TRAFFIC ENGINEE                    45300 - TE PAVE MARK      Expense
# 6985  TRAFFIC ENGINEE  45800 - TE BICYCLE AND PEDESTRIAN SVCS      Expense
# 7004  TRAFFIC ENGINEE                     45600 - TE SERVICES      Expense
# 7045  TRAFFIC ENGINEE                      45100 - TE SIGNING      Expense
# 7051  TRAFFIC ENGINEE                         45400 - TE COMM      Expense
# 7055             FIRE               30110 - FIRE GEN FIELD OP      Expense
# 7178           POLICE                    31100 - POLICE FIELD      Expense
# 7995             FIRE  30280 - FIRE COMMUNITY OUTREACH & EDUC      Expense
# 8273      ENGINEERING        40138 - ENG SIDEWALKS PATH MAINT      Expense
# 8541          LIBRARY                  50400 - LIB FACILITIES      Expense
# 8623      ENGINEERING             40121 - ENG STREETS GENERAL      Expense
#
#                  Character Code           Object       2015       2016  \
# 59    57 - INTER DEPART CHARGES      ENGINEERING  -63972.24  -49280.07
# 61    57 - INTER DEPART CHARGES   FLEET SERVICES  -60600.53  -93501.38
# 114   57 - INTER DEPART CHARGES      ENGINEERING  -26500.98  -23211.29
# 820   57 - INTER DEPART CHARGES  TRAFFIC ENGINEE       0.00       0.00
# 1235  57 - INTER DEPART CHARGES        INSURANCE       0.00       0.00
# 1334  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE       0.00      13.69
# 1485  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE       0.00     112.50
# 1493  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE       0.00     117.86
# 1757  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE       0.00     744.79
# 1960  57 - INTER DEPART CHARGES      ENGINEERING       0.00   11453.00
# 2462  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE      41.11       0.00
# 2467  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE      41.79      96.55
# 3550  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE     377.21     363.02
# 3551  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE     377.22     363.04
# 3552  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE     377.23     363.05
# 3721  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE     492.51    1137.10
# 3898  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE     618.19     144.81
# 4037  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE     714.16     243.14
# 4084  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE     754.45     726.10
# 4085  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE     754.45     726.10
# 4086  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE     754.45     726.10
# 4141  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE     800.00       0.00
# 4271  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE     929.64     867.20
# 4288  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE     945.37     485.22
# 4426  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE    1131.67    1089.14
# 4427  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE    1131.68    1089.15
# 4494  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE    1237.66       0.00
# 4632  57 - INTER DEPART CHARGES          STREETS    1425.00       0.00
# 4678  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE    1508.90    1452.20
# 4865  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE    1886.13    1815.24
# ...                         ...              ...        ...        ...
# 5232  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE    3017.81    2904.39
# 5234  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE    3022.82    2056.58
# 5279  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE    3188.58    1550.13
# 5467  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE    4124.91    4514.28
# 5565  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE    4739.65    4305.87
# 5654  57 - INTER DEPART CHARGES      ENGINEERING    5500.00    4909.00
# 5672  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE    5658.38    5445.73
# 5751  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE    6392.27    5808.78
# 5795  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE    6790.06    7134.16
# 6031  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE    9732.82    3925.23
# 6052  57 - INTER DEPART CHARGES      ENGINEERING   10019.94    9272.00
# 6112  57 - INTER DEPART CHARGES      ENGINEERING   10900.00    8181.00
# 6113  57 - INTER DEPART CHARGES      ENGINEERING   10900.00    9817.00
# 6251  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE   14026.67       0.00
# 6350  57 - INTER DEPART CHARGES        INSURANCE   17109.00   26241.00
# 6555  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE   26983.33   13120.26
# 6726  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE   37798.95   28627.02
# 6833  57 - INTER DEPART CHARGES   FLEET SERVICES   51579.75  -26574.57
# 6847  57 - INTER DEPART CHARGES     WORKERS COMP   53079.00   54929.00
# 6983  57 - INTER DEPART CHARGES   FLEET SERVICES   81208.48   30048.41
# 6985  57 - INTER DEPART CHARGES   FLEET SERVICES   81436.50   20032.27
# 7004  57 - INTER DEPART CHARGES   FLEET SERVICES   88546.44   16025.83
# 7045  57 - INTER DEPART CHARGES   FLEET SERVICES  101887.07  447206.79
# 7051  57 - INTER DEPART CHARGES   FLEET SERVICES  103782.80   36058.09
# 7055  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE  105221.23  104801.26
# 7178  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE  180720.06  192614.14
# 7995  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE        NaN      57.78
# 8273  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE        NaN        NaN
# 8541  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE        NaN        NaN
# 8623  57 - INTER DEPART CHARGES  TRAFFIC ENGINEE        NaN        NaN
#
#            2017       2018
# 59    -64253.92  -82807.72
# 61    -40963.32  -50180.83
# 114    -7738.09  -24863.05
# 820        8.00       0.00
# 1235   39497.00   28937.00
# 1334       0.00       0.00
# 1485       0.00       0.00
# 1493     548.00       0.00
# 1757    3306.09     387.09
# 1960   11452.00   11452.00
# 2462       0.00       0.00
# 2467      71.70       0.00
# 3550     374.00     377.94
# 3551     373.30     377.91
# 3552     373.31     377.92
# 3721     335.20     326.56
# 3898    1246.80       0.00
# 4037     328.45       0.00
# 4084     744.64     755.87
# 4085     744.65     755.87
# 4086     821.83    1133.77
# 4141       0.00       0.00
# 4271    1098.20     970.97
# 4288      98.50       0.00
# 4426    1116.95    1133.77
# 4427    1193.40    1511.72
# 4494     252.22       0.00
# 4632       0.00       0.00
# 4678    1566.47    1889.63
# 4865    2247.53    3779.28
# ...         ...        ...
# 5232    2978.53    3023.42
# 5234     840.11     814.37
# 5279    1659.36    3658.58
# 5467    3727.14    3390.37
# 5565    3815.10    2754.84
# 5654    4909.00    4909.00
# 5672    4497.34     377.92
# 5751    6650.99    7585.92
# 5795    6704.47    6802.69
# 6031    7064.86    8718.87
# 6052    9272.00    9272.00
# 6112    8181.00   -9295.30
# 6113    9817.00    9817.00
# 6251       0.00       0.00
# 6350       0.00       0.00
# 6555   11151.30   19798.02
# 6726   27133.62   35156.17
# 6833   32756.47   18646.85
# 6847   76335.00   78625.00
# 6983   63804.25   59598.33
# 6985   53104.30   50358.07
# 7004   51706.54   49559.86
# 7045   63013.14   52596.34
# 7051   79591.45   74560.88
# 7055  106984.50  120546.11
# 7178  182225.10  235375.90
# 7995      27.69      29.60
# 8273      89.63       0.00
# 8541        NaN       0.00
# 8623        NaN     550.00
#
# [62 rows x 9 columns]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-d386dfb410eb> in <module>
#      15 for i in bill:
#      16     agency = i[0][0]
# ---> 17     obj = i[0][1]
#      18     ag1 = charge[agency][obj]
#      19     try:
#
# IndexError: string index out of range

# %%
revenue_dataset = streets_dataset[streets_dataset["Account Type"] == "Revenue"]
expense_dataset = streets_dataset[streets_dataset["Account Type"] == "Expense"]

tot_revenue = revenue_dataset["2018"].abs().sum() / 10 **6
tot_expense = expense_dataset["2018"].abs().sum() / 10**6

label_column = Series(["Revenue", "Expenses"])
series_column = Series([tot_revenue, tot_expense])

table = DataFrame({"type":label_column, "Cost (in millions)":series_column})
ax = table.plot.bar(x = 'type', y = 'Cost (in millions)', legend = False)
ax.set_xlabel("")
ax.set_ylabel("Cost in millions")
ax.set_title("Revenue and Expenses")

# %%
expenses_by_type = expense_dataset.groupby(["Character Code"])
expense_types = expenses_by_type["2018"].sum()
ax = expense_types.plot.pie(figsize = (6,6))
ax.set_ylabel("")
ax.set_title("Expense Sources of Streets")

# %%
interdep_billing = expense_dataset[expense_dataset["Character Code"] == '58 - INTER DEPART BILLING']
objects = interdep_billing.groupby(["Object"])["2015"].sum().abs()
#series1 = objects.tail(2)
#other = objects.sum() - series1.sum()
#series2 = Series([other], index=['Other'])

#plot_data = pd.concat(objects)
ax2 = objects.plot.pie(figsize=(6,6), autopct='%d%%')
ax2.set_ylabel("")
ax2.set_title("Interdepartmental Billing for Streets")

# %%
interdep_charges = expense_dataset[expense_dataset["Character Code"] == '57 - INTER DEPART CHARGES']
objects = interdep_charges.groupby(["Object"])["2018"].sum().sort_values()

series1 = objects.tail(2)
other = objects.sum() - series1.sum()
series2 = Series([other], index=['Other'])

plot_data = pd.concat([series1, series2])
ax3 = plot_data.plot.pie(figsize=(6,6), autopct='%d%%')
ax3.set_ylabel("")
ax3.set_title("Interdepartmental Charges for Streets")

# %%
revenue_types = revenue_dataset.groupby(["Character Code"])["2018"].sum().abs()
ax = revenue_types.plot.pie()
ax.set_ylabel("")
ax.set_title("Revenue Sources")

# %%
total_revenue_all_years = Series([revenue_dataset["2015"].sum(), revenue_dataset["2016"].sum(), revenue_dataset["2017"].sum(), revenue_dataset["2018"].sum()]).abs() / 10**6
df = DataFrame({"Year": Series([2015, 2016, 2017, 2018]), "Revenue (millions)": total_revenue_all_years})
ax = df.plot.line(x="Year", y= "Revenue (millions)",ylim=[0, total_revenue_all_years.max() * 1.5], legend=False, figsize = (12, 6))
ax.set_ylabel("Millions of dollars")
ax.set_title("Revenue over time")
ax.set_xticks([2015, 2016, 2017, 2018])

# %%
total_expenses_all_years = Series([expense_dataset["2015"].sum(), expense_dataset["2016"].sum(), expense_dataset["2017"].sum(), expense_dataset["2018"].sum()]).abs() / 10**6
df = DataFrame({"Year": Series([2015, 2016, 2017, 2018]), "Revenue (millions)": total_expenses_all_years})
ax = df.plot.line(x="Year", y= "Revenue (millions)",ylim=[0, total_expenses_all_years.max() * 1.5], legend=False, figsize = (12,6))
ax.set_ylabel("Millions of dollars")
ax.set_title("Expenses over time")
ax.set_xticks([2015, 2016, 2017, 2018])

# %%
objects = int_billing.groupby(["Object"])["2018"].sum().abs().sort_values(ascending = False)/1000
objects = objects.rename(lambda s:s[19:] )
ax2 = objects.plot.bar(figsize=(10,6))
ax2.set_ylabel("Expense in Thousands of Dollars")
ax2.set_xlabel("Object")
ax2.set_title("Interdepartmental Billing by Object")

# %%
objects = int_charges.groupby(["Object"])["2018"].sum().abs().sort_values(ascending=False).head(5)
# Todo: add misc.
objects = objects.rename(lambda s:s[17:] )

ax2 = objects.plot.pie(figsize=(6,6), autopct='%d%%')
ax2.set_ylabel("")
ax2.set_title("Interdepartmental Charges by Object")

# %%
# Agencies that have the most interdepartmental billing
objects = int_billing.groupby(["Agency"])["2018"].sum().abs().sort_values(ascending=False)
# Todo: add misc.
objects = objects.rename(lambda s:s[5:] )

ax2 = objects.plot.pie(figsize=(6,6), autopct='%d%%')
ax2.set_ylabel("")
ax2.set_title("Interdepartmental Billing by Agency")

# %%
# Agencies that have the most interdepartmental charges
objects = int_charges.groupby(["Agency"])["2018"].sum().abs().sort_values(ascending=False).head(6)
# Todo: add misc.
objects = objects.rename(lambda s:s[5:] )

ax2 = objects.plot.pie(figsize=(6,6), autopct='%d%%')
ax2.set_ylabel("")
ax2.set_title("Interdepartmental Charges by Agency")

# %%
objects = int_billing.groupby(["Organization"])["2018"].sum().abs().sort_values(ascending = False).head(8)/1000
objects = objects.rename(lambda s:s[8:] )
ax2 = objects.plot.bar(figsize=(6,6))
ax2.set_ylabel("Millions of Dollars")
ax2.set_xlabel("Object")
ax2.set_title("Interdepartmental Billing by Org")

# %%
objects = int_charges.groupby(["Organization"])["2018"].sum().abs().sort_values(ascending = False).head(30)/1000000
objects = objects.rename(lambda s:s[8:] )
ax2 = objects.plot.bar(figsize=(12,6))
ax2.set_ylabel("Millions of Dollars")
ax2.set_xlabel("Object")
ax2.set_title("Interdepartmental Charges by Org")

# %%
def graph_charges(column1, value, column2, trim=None):
    # Isolates only data points in column1 matching "value",
    # Then graphs them grouped by column2.
    # Trims the first trim characters off of the labels
    if(trim == None):
        trim = 0
    # obj is string
    billing = int_charges[int_charges[column1].str.contains(value)]
    objects = billing.groupby([column2])["2018"].sum().abs().sort_values(ascending=False).head(10)
    # Todo: add misc.
    objects = objects.rename(lambda s:s[trim:] )

    ax2 = objects.plot.pie(figsize=(6,6), autopct='%d%%')
    ax2.set_ylabel("")
    ax2.set_title("Charges in " + column1.lower() + " " + value.lower() + " by " + column2.lower())
    return ax2

# %%
def graph_billing(column, org, column2, trim=None):
    if trim == None:
        trim = 0
    # obj is string
    billing = int_billing[int_billing[column].str.contains(org)]
    objects = billing.groupby([column2])["2018"].sum().abs().sort_values(ascending=False).head(10)
    # Todo: add misc.
    objects = objects.rename(lambda s:s[trim:] )

    ax2 = objects.plot.pie(figsize=(6,6), autopct='%d%%')
    ax2.set_ylabel("")
    ax2.set_title("Billing in " + column.lower() + " " + org.lower() + " by " + column2.lower() )
    return ax2

# %%
#1 
graph_billing("Agency", "40 -  ENGINEERING", "Object", 18)

# %%
#1 
graph_billing("Agency", "40 -  ENGINEERING", "Organization", 7)

# %%
#2
graph_billing("Agency", "TRAFFIC ENGINEERING", "Object", 18)

# %%
#2
graph_billing("Agency", "TRAFFIC ENGINEERING", "Organization", 7)

# %%
#3
graph_billing("Agency", "INFORMATION TECHNOLOGY", "Object")

# %%
#3
graph_billing("Agency", "INFORMATION TECHNOLOGY", "Organization", 7)

# %%
graph_charges("Agency","STREETS", "Object", 18)

# %%
graph_charges("Agency","STREETS", "Organization", 7)

# %%
graph_charges("Agency","POLICE", "Object", 18)

# %%
graph_charges("Agency","POLICE", "Organization", 7)

# %%
graph_charges("Agency","FIRE", "Object", 18)

# %%
graph_charges("Agency","FIRE", "Organization", 7)

# %%
graph_billing("Object", "FLEET SERVICES", "Agency", 5)

# %%
graph_charges("Object", "FLEET SERVICES", "Agency", 5)
